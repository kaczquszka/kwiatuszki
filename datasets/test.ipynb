# %%
import pandas as pd
import numpy as np
links = pd.read_csv('links.csv').iloc[:, 0].to_numpy()
uni = pd.read_csv('plants_unique.csv').iloc[:, 0].to_numpy()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 links = pd.read_csv('links.csv').iloc[:, 0].to_numpy()
#       4 uni = pd.read_csv('plants_unique.csv').iloc[:, 0].to_numpy()
#
# ...

# %%
#check if there are any entries of plants in unique that dont correcpopnd to any link entry
for n in uni:
    if n not in links:
        print(n)

# %%
uni = pd.read_csv('plants_unique.csv')
links = pd.read_csv('links.csv')
df = pd.concat([uni, links],axis=1)
df.to_csv('plants_with_links.csv')

# %%
plants_links = pd.read_csv("plants_links.csv")
session_statepage = plants_links.loc[plants_links['Names']=='Cucumbers', 'Page Title'].values[0]
session_statepage
# Out:
# 'Cucumber'

# %%
df = pd.read_csv('answers_tab.csv', sep='\t')

df['sentiment'].value_counts()
# Out:
# sentiment
# positive    736
# negative    735
# neutral     726
# Name: count, dtype: int64

# %%
df = pd.read_csv('twitter_training.csv')
res = pd.DataFrame(columns=['text','senitment'])
for x in range(df.shape[0]):
    text = str(df.iloc[x]['text'])
    if len(text)<40:
        res.loc[res.shape[0]]=[text, df.iloc[x]['sentiment']]

# %%
res.to_csv('skibidi')
