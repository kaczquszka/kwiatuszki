# %%
import pandas as pd
import numpy as np
links = pd.read_csv('links.csv').iloc[:, 0].to_numpy()
uni = pd.read_csv('plants_unique.csv').iloc[:, 0].to_numpy()

# %%
for n in uni:
    if n not in links:
        print(n)
# Out:
# Chinese Evergreen
# Fuchsia
# Calla Lily
# Agave
